# %% [markdown]
# # Lesson 3 Activities: Inheritance
# These activities will allow you to demonstrate your ability to:
# * Create new classes that inherit the attributes and methods of an existing class.
# * Define inherited classes that have different properties than their parent classes.
# * Use overriding to replace a property in a parent class with a property in an inherited class.

# %% [markdown]
# ## Activity 0
# Before beginning, create a class `Noun` to use as the starting point for the activities in this section. The `Noun` class can be anything you wish, as long as it meets the following criteria:
#
# * Do not use people or animals.
# * The category must be broad enough to include different examples of the category.
# * It must represent a real-life object.
#
# Include at least three attributes that are common to most (if not all) instances of the `Noun`. Use appropriate naming conventions. If you created a `Noun` class for an earlier activity in this course, you are welcome to use it for the activities in this page, or you can create a new one.
#
# Implement the appropriate `__init__` and `display` methods to create and display objects respectively.

# %%
class motor_bike:
    engine_size = ""
    purpose = ""
    handle_bars = ""
    name = ""
    def __init__(self, model, brand, engine_size, purpose, ):
        self.model = model
        self.brand = brand
        self.engine_size = engine_size
        self.purpose = purpose
    def display_info(self):
        print(self.model)
        print(self.brand)
        print(self.engine_size)
        print(self.purpose)

motor_bike_1 = motor_bike("Yamaha", "R1_World_GP", "1000", "Racing")
motor_bike_1.display_info()
motor_bike_2 = motor_bike("Buelle", "S2_Lightning", "1340", "Cruising")
motor_bike_2.display_info()
motor_bike_3 = motor_bike("Yamaha", "RXS_100", "100", "City")
motor_bike_3.display_info()
motor_bike_4 = motor_bike("Yamaha", "FZ6_Fazer", "600", "Street_Fighter")
motor_bike_4.display_info()
# Out:
# Yamaha
# R1_World_GP
# 1000
# Racing
# Buelle
# S2_Lightning
# 1340
# Cruising
# Yamaha
# RXS_100
# 100
# City
# Yamaha
# FZ6_Fazer
# 600
# Street_Fighter

# %% [markdown]
# ## Activity 1
# Use inheritance to create another class that will inherit from the `Noun` class. Create two objects using the new class and display each object's information using the `display` method.
#
# As an example from this lesson, we started with an `Animal` class, created a `Mammal` class that inherits from `Animal`, and then created two `Mammal` objects. You will need to identify an appropriate class based on your own `Noun` class as well as appropriate objects that represent the inherited class.

# %%
class motor_bike:
    engine_size = ""
    purpose = ""
    handle_bars = ""
    name = ""
    def __init__(self, brand, model, engine_size, purpose):
        self.engine_size = engine_size
        self.purpose = purpose
        self.brand = brand
        self.model = model
        
    def display_info(self):
        print(self.engine_size)
        print(self.purpose)
        print(self.brand)
        print(self.model)

class bike_sales(motorbike):
    price = None
    def __init__(self, brand, model, engine_size, purpose, price):
        self.brand = brand
        self.model = model
        self.engine_size = engine_size
        self.purpose = purpose
        self.price = price
    def display(self):
        print("Manufacturer: " + self.brand)
        print("Model: " + self.model)
        print("Capacity: " + self.engine_size)
        print("Designed for: " + self.purpose)
        print("At the limited time price of:" + self.price)


obj_mb = bike_sales("Buelle", "S2_Lightning", "1340", "Cruising", "£13,580")
obj_mb.display()
obj_mb_2 = bike_sales("Yamaha", "R1_World_GP_Edition", "1000", "Racing", "£22,000")
obj_mb_2.display()
#motor_bike_1 = motor_bike("Yamaha", "R1_World_GP_Edition", "1000", "Racing")
#motor_bike_1.display_info()
#motor_bike_2 = motor_bike("Buelle", "S2_Lightning", "1340", "Cruising")
#motor_bike_2.display_info()
#motor_bike_4 = motor_bike("Yamaha", "FZ6_Fazer", "600", "Street_Fighter", )
#motor_bike_4.display_info()
# Out:
# Manufacturer: Buelle
# Model: S2_Lightning
# Capacity: 1340
# Designed for: Cruising
# At the limited time price of:£13,580
# Manufacturer: Yamaha
# Model: R1_World_GP_Edition
# Capacity: 1000
# Designed for: Racing
# At the limited time price of:£22,000

# %% [markdown]
# ## Activity 2
# Add at least two attributes to the new class created in the previous activity. These attributes should be different from the attributes in the original `Noun` class and specific to the new class.
#
# > As an example from the lesson, the Animal class included the attributes of name and place. The Mammal class that inherits from the Animal class would include mammal-specific attributes, such as gender and fur length.
#
# Override the `__init__` and `display` methods to display the new attributes, and then create at least two new objects based on the inherited class and display them with the class attributes.

# %%
class motor_bike:
    engine_size = None
    purpose = None
    handle_bars = None
    name = None
    def __init__(self, brand, model, engine_size, purpose):
        self.brand = brand
        self.model = model
        self.engine_size = engine_size
        self.purpose = purpose
    def display_info(self):
        print(self.brand)
        print(self.model)
        print(self.engine_size)
        print(self.purpose)

class bike_sales(motor_bike):
    price = None
    def __init__(self, brand, model, engine_size, purpose, price):
        motor_bike.__init__(self, brand, model, engine_size, purpose)
        self.price = price
    def display(self):
        print("Manufacturer: " + self.brand)
        print("Model: " + self.model)
        print("Capacity: " + self.engine_size)
        print("Designed for: " + self.purpose)
        print("At the limited time price of:" + self.price)


obj_mb_1 = bike_sales("Buelle", "S2_Lightning", "1340", "Cruising", "£13,580")
obj_mb_1.display()
obj_mb_2 = bike_sales("Yamaha", "R1_World_GP_Edition", "1000", "Racing", "£22,000")
obj_mb_2.display()
obj_mb_3 = bike_sales("Ducatti", "Monster", "1200", "Street_Fighter", "£15,580")
obj_mb_3.display()
obj_mb_3 = bike_sales("Triumph", "Speed_Triple", "1200", "Endurance", "£18,700")
#motor_bike_1 = motor_bike("Yamaha", "R1_World_GP_Edition", "1000", "Racing")
#motor_bike_1.display_info()
#motor_bike_2 = motor_bike("Buelle", "S2_Lightning", "1340", "Cruising")
#motor_bike_2.display_info()
#motor_bike_4 = motor_bike("Yamaha", "FZ6_Fazer", "600", "Street_Fighter", )
#motor_bike_4.display_info()
# Out:
# Manufacturer: Buelle
# Model: S2_Lightning
# Capacity: 1340
# Designed for: Cruising
# At the limited time price of:£13,580
# Manufacturer: Yamaha
# Model: R1_World_GP_Edition
# Capacity: 1000
# Designed for: Racing
# At the limited time price of:£22,000
# Manufacturer: Ducatti
# Model: Monster
# Capacity: 1200
# Designed for: Street_Fighter
# At the limited time price of:£15,580

# %% [markdown]
# ## Activity 3
# Create a second and a third class that inherit from the `Noun` class you started with.
# * Include at least three class-specific attributes for each class.
#
# For each of the new classes, override the `__init__` and `display` methods to display the new attributes and then create at least two new objects based on the inherited class and display them with the class attributes.

# %%
class motor_bike:
    engine_size = None
    purpose = None
    handle_bars = None
    name = None
    def __init__(self, brand, model, engine_size, purpose):
        self.brand = brand
        self.model = model
        self.engine_size = engine_size
        self.purpose = purpose
    def display_info(self):
        print("bikes I want:")
        print(self.brand)
        print(self.model)
        print(self.engine_size)
        print(self.purpose)

class bike_sales(motor_bike):
    price = None
    def __init__(self, brand, model, engine_size, purpose, price):
        motor_bike.__init__(self, brand, model, engine_size, purpose)
        self.price = price
    def display(self):
        print("Manufacturer: " + self.brand)
        print("Model: " + self.model)
        print("Capacity: " + self.engine_size)
        print("Designed for: " + self.purpose)
        print("Quality at a great price:" + self.price)
        
class bike_hire(motor_bike):
    price_per_day = None
    def __init__(self, brand, model, purpose, price_per_day):
        motor_bike.__init__(self, brand, model, purpose)
        self.price_per_day = price_per_day
    def display(self):
        motor_bike.display(self)
        print(self.price_per_day)
        
class helmet(bike_hire):
    size = None
    def __init__(self, brand, item, size, purpose, price_per_day):
        bike_hire__init__(self, brand, purpose, price_per_day)
        self.item = item
        self.size = size
    def display(self):
        bike_hire.display(self)
        print(self.item)
        

obj_mb_1 = bike_sales("Buelle", "S2 Lightning", "1340", "Cruising", "£13,580")
obj_mb_1.display()
obj_mb_2 = bike_sales("Yamaha", "R1 World GP Edition", "1000", "Racing", "£22,000")
obj_mb_2.display()
obj_mb_3 = bike_sales("Ducatti", "Monster", "1200", "Street Fighter", "£15,580")
obj_mb_3.display()
obj_mb_3 = bike_sales("Triumph", "Speed_Triple", "1200", "Endurance", "£18,700")
obj_mb_3.display()
obj_mb_4 = bike_sales("Honda", "CR", "450", "Moto-X", "£135.00")
obj_mb_4.display()
obj_mb_5 = bike_sales("Suzuki", "RS", "250", "Moto-X", "£99.99")
obj_mb_5.display()
obj_mb_5 = bike_sales("Alpine Stars", "boots", "M/L/XL", "off road", "£6.99")
obj_mb_5.display()
obj_mb_5 = bike_sales("Dainese", "gloves", "L/XL", "off road", "£5.99")
obj_mb_5.display()
print("Hire bikes are charged per day, not including insurance:")
motor_bike_1 = motor_bike("Yamaha", "R1_World_GP_Edition", "1000", "Racing")
motor_bike_1.display_info()
motor_bike_2 = motor_bike("Buelle", "S2_Lightning", "1340", "Cruising")
motor_bike_2.display_info()
motor_bike_4 = motor_bike("Yamaha", "FZ6_Fazer", "600", "Street_Fighter")
motor_bike_4.display_info()
# Out:
# Manufacturer: Buelle
# Model: S2 Lightning
# Capacity: 1340
# Designed for: Cruising
# Quality at a great price:£13,580
# Manufacturer: Yamaha
# Model: R1 World GP Edition
# Capacity: 1000
# Designed for: Racing
# Quality at a great price:£22,000
# Manufacturer: Ducatti
# Model: Monster
# Capacity: 1200
# Designed for: Street Fighter
# Quality at a great price:£15,580
# Manufacturer: Triumph
# Model: Speed_Triple
# Capacity: 1200
# Designed for: Endurance
# Quality at a great price:£18,700
# Manufacturer: Honda
# Model: CR
# Capacity: 450
# Designed for: Moto-X
# Quality at a great price:£135.00
# Manufacturer: Suzuki
# Model: RS
# Capacity: 250
# Designed for: Moto-X
# Quality at a great price:£99.99
# Manufacturer: Alpine Stars
# Model: boots
# Capacity: M/L/XL
# Designed for: off road
# Quality at a great price:£6.99
# Manufacturer: Dainese
# Model: gloves
# Capacity: L/XL
# Designed for: off road
# Quality at a great price:£5.99
# ...

# %% [markdown]
# ## Activity 4
# Using the three inherited classes you have already created, use the `__init__` method of the `Noun` class to set the values of the original attributes defined in the `Noun` class.
#
# Create two objects for each of the three inherited classes and display all attributes, including attributes from the original `Noun` class.

# %%
class motor_bike:
    handle_bars = None
    name = None
    engine_size = None
    purpose = None
    def __init__(self, brand, model, engine_size, purpose):
        self.brand = brand
        self.model = model
        self.engine_size = engine_size
        self.purpose = purpose
    def display_info(self):
        print(self.brand)
        print(self.model)
        print(self.engine_size)
        print(self.purpose)

class bike_sales(motor_bike):
    price = None
    def __init__(self, brand, model, engine_size, purpose, price):
        motor_bike.__init__(self, brand, model, engine_size, purpose)
        self.price = price
    def display(self):
        print("Manufacturer: " + self.brand)
        print("Model: " + self.model)
        print("Capacity: " + self.engine_size)
        print("Designed for: " + self.purpose)
        print("Quality at a great price:" + self.price)
        
class bike_hire(bike_sales):
    price_per_day = None
    def __init__(self, brand, model, purpose, price_per_day):
        motor_bike.__init__(self, brand, model, purpose)
        self.price_per_day = price_per_day
    def display(self):
        for price_per_day in self.bike_hire:
            print("Per day cost: " + self.price_per_day)
            bike_hire.display(price_per_day)
            print(self.price_per_day)
        
class gear_hire(bike_hire):
    size = None
    def __init__(self, brand, item, purpose, size, price_per_day):
        motor_bike__init__(self, brand, purpose,)
        bike_hire__init__( price_per_day)
        self.item = item
        self.size = size
    def display(self):
        print("Clothing type: " + self.item)
        print("Availible sizes: " + self.size)
        bike_hire.display(self)
        print(self.item)
        

obj_mb_1 = bike_sales("Buelle", "S2 Lightning", "1340", "Cruising", "£13,580")
obj_mb_1.display()
obj_mb_2 = bike_sales("Yamaha", "R1 World GP Edition", "1000", "Racing", "£22,000")
obj_mb_2.display()
obj_mb_3 = bike_sales("Ducatti", "Monster", "1200", "Street Fighter", "£15,580")
obj_mb_3.display()
obj_mb_3 = bike_sales("Triumph", "Speed_Triple", "1200", "Endurance", "£18,700")
obj_mb_3.display()
obj_mb_4 = bike_hire("Honda", "CR", "450", "Moto-X", "£135.00")
obj_mb_4.display()
obj_mb_5 = bike_hire("Suzuki", "RS", "250", "Moto-X", "£99.99")
obj_mb_5.display()
obj_mb_5 = gear_hire("Alpine Stars", "boots", "M/L/XL", "off road", "£6.99")
obj_mb_5.display()
obj_mb_5 = gear_hire("Dainese", "gloves", "L/XL", "off road", "£5.99")
obj_mb_5.display()




print("Hire bikes and equipment are charged per day, not including insurance:")
# Out:
# Manufacturer: Buelle
# Model: S2 Lightning
# Capacity: 1340
# Designed for: Cruising
# Quality at a great price:£13,580
# Manufacturer: Yamaha
# Model: R1 World GP Edition
# Capacity: 1000
# Designed for: Racing
# Quality at a great price:£22,000
# Manufacturer: Ducatti
# Model: Monster
# Capacity: 1200
# Designed for: Street Fighter
# Quality at a great price:£15,580
# Manufacturer: Triumph
# Model: Speed_Triple
# Capacity: 1200
# Designed for: Endurance
# Quality at a great price:£18,700
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38848\809346692.py in <module>
#      60 obj_mb_3 = bike_sales("Triumph", "Speed_Triple", "1200", "Endurance", "£18,700")
#      61 obj_mb_3.display()
# ---> 62 obj_mb_4 = bike_hire("Honda", "CR", "450", "Moto-X", "£135.00")
#      63 obj_mb_4.display()
# ...

# %% [markdown]
# ## Activity 5
# Create a class that inherits from your initial inherited class. Include at least one attribute specific to this class.
#
# Create two objects based on this class and display all attributes for each object.
#
# > As an example from the lesson, we started with an `Animal` class and then created a `Mammal` class that inherits from `Animal`. We could have also created additional classes that inherit from `Mammal`, such as `Dog` and `Cat`, which would have their own class-specific attributes.

# %%
# your code here

# %% [markdown]
# ## Activity 6
# Create another class that inherits from the class created for the previous activity. For the new class, create at least one class-specific attribute and one object based on the class.
#
# Use `isinstance()` to verify that the new object is an instance of each of the parent classes of the new class.

# %%
# your code here
