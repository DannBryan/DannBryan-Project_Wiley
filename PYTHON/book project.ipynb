# %%
#Convert a string to lowercase characters.  /
#Split the lowercase string into individual words. /
#Count the number of words in the lowercase string./ 
#Determine the number of distinct words in the lowercase string./ 
#Calculate the number of times each word appears in the lowercase string.
#Remove the punctuation from the lowercase string.
#Perform a count analysis on the text without punctuation characters.



#count = 0

book = "Imagine a vast sheet of paper on which straight Lines, Triangles, Squares, Pentagons, Hexagons, and other figures, instead of remaining fixed in their places, move freely about, on or in the surface, but without the power of rising above or sinking below it, very much like shadows--only hard and with luminous edges--and you will then have a pretty correct notion of my country and countrymen.  Alas, a few years ago, I should have said 'my universe':  but now my mind has been opened to higher views of things."
s_lower = book.lower() #lower case
words = s_lower.split()  # slpit words
print(len(words))     #print number of words
print(len(set(words)))  # print distinct words

frq_occur = dict()     #make dict to hold frequency


for k in words:         #find frequency of words
    if k in frq_occur: 
        frq_occur[k] += 1                   
    else: 
        frq_occur[k] = 1

print(frq_occur)    print freq of words
# Out:
#   File "C:\Users\mattb\AppData\Local\Temp\ipykernel_18112\3895051260.py", line 32
#     print freq of words
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(freq of words)?

# %%
words = s_lower.split()
print(words) #test
# Out:
# ['imagine', 'a', 'vast', 'sheet', 'of', 'paper', 'on', 'which', 'straight', 'lines,', 'triangles,', 'squares,', 'pentagons,', 'hexagons,', 'and', 'other', 'figures,', 'instead', 'of', 'remaining', 'fixed', 'in', 'their', 'places,', 'move', 'freely', 'about,', 'on', 'or', 'in', 'the', 'surface,', 'but', 'without', 'the', 'power', 'of', 'rising', 'above', 'or', 'sinking', 'below', 'it,', 'very', 'much', 'like', 'shadows--only', 'hard', 'and', 'with', 'luminous', 'edges--and', 'you', 'will', 'then', 'have', 'a', 'pretty', 'correct', 'notion', 'of', 'my', 'country', 'and', 'countrymen.', 'alas,', 'a', 'few', 'years', 'ago,', 'i', 'should', 'have', 'said', "'my", "universe':", 'but', 'now', 'my', 'mind', 'has', 'been', 'opened', 'to', 'higher', 'views', 'of', 'things.']

# %%
book = "Imagine a vast sheet of paper on which straight Lines, Triangles, Squares, Pentagons, Hexagons, and other figures, instead of remaining fixed in their places, move freely about, on or in the surface, but without the power of rising above or sinking below it, very much like shadows--only hard and with luminous edges--and you will then have a pretty correct notion of my country and countrymen.  Alas, a few years ago, I should have said 'my universe':  but now my mind has been opened to higher views of things."
s_lower = book.lower()
words = s_lower.split()
s_lower.strip(" \" :, ")
print(len(words))
print(len(set(words)))

frq_occur = dict()


for k in words:
    if k in frq_occur: 
        frq_occur[k] += 1                   
    else: 
        frq_occur[k] = 1

print(frq_occur)
# Out:
# 88
# 73
# {'imagine': 1, 'a': 3, 'vast': 1, 'sheet': 1, 'of': 5, 'paper': 1, 'on': 2, 'which': 1, 'straight': 1, 'lines,': 1, 'triangles,': 1, 'squares,': 1, 'pentagons,': 1, 'hexagons,': 1, 'and': 3, 'other': 1, 'figures,': 1, 'instead': 1, 'remaining': 1, 'fixed': 1, 'in': 2, 'their': 1, 'places,': 1, 'move': 1, 'freely': 1, 'about,': 1, 'or': 2, 'the': 2, 'surface,': 1, 'but': 2, 'without': 1, 'power': 1, 'rising': 1, 'above': 1, 'sinking': 1, 'below': 1, 'it,': 1, 'very': 1, 'much': 1, 'like': 1, 'shadows--only': 1, 'hard': 1, 'with': 1, 'luminous': 1, 'edges--and': 1, 'you': 1, 'will': 1, 'then': 1, 'have': 2, 'pretty': 1, 'correct': 1, 'notion': 1, 'my': 2, 'country': 1, 'countrymen.': 1, 'alas,': 1, 'few': 1, 'years': 1, 'ago,': 1, 'i': 1, 'should': 1, 'said': 1, "'my": 1, "universe':": 1, 'now': 1, 'mind': 1, 'has': 1, 'been': 1, 'opened': 1, 'to': 1, 'higher': 1, 'views': 1, 'things.': 1}

# %%
['haythem', 'is', 'eating', 'tacos', 'haythem', 'loves', 'tacos']
import string          #import the string module 
                      #use the built-in string.punctuation method to create a list of all punctuation marks
punctuation_list =  list(string.punctuation)
                            
print(punctuation_list)            #display the punctuation_list
 
#w = ["haythem!","is","eating","tacos.",".haythem","loves","tacos","",":"]
w_clean = list()
######################################################do not change the code above this line.
 
frq_occur = dict()


for word in w:
    if len(word) == 0 or (len(word) == 1 and word in punctuation_list):
        continue
    elif word[0] in punctuation_list:
        word = word[1:]
    elif word[-1] in punctuation_list:
        word = word[:-1]
    w_clean.append(word)

print(frq_occur)

print(w_clean)
print(len(w_clean))
# Out:
# ['!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~']
# {}
# ['haythem', 'is', 'eating', 'tacos', 'haythem', 'loves', 'tacos']
# 7

# %%
import string

punctuation_list = list(string.punctuation)

#w = ["haythem!","is","eating","tacos.",".haythem","loves","tacos","",":"]
w_clean = []

for word in w:
    if len(word) == 0 or (len(word) == 1 and word in punctuation_list):
        continue
    elif word[0] in punctuation_list:
        word = word[1:]
    elif word[-1] in punctuation_list:
        word = word[:-1]
    w_clean.append(word)

print(w_clean)
print(len(w_clean))
# Out:
# ['haythem', 'is', 'eating', 'tacos', 'haythem', 'loves', 'tacos']
# 7

# %%
#final code


book = "Imagine a vast sheet of paper on which straight Lines, Triangles, Squares, Pentagons, Hexagons, and other figures, instead of remaining fixed in their places, move freely about, on or in the surface, but without the power of rising above or sinking below it, very much like shadows--only hard and with luminous edges--and you will then have a pretty correct notion of my country and countrymen.  Alas, a few years ago, I should have said 'my universe':  but now my mind has been opened to higher views of things."
s_lower = book.lower()
words = s_lower.split()

punctuation_list = list(string.punctuation)

print(punctuation_list)

#frq_occur = dict()


for words in w:
    if len(word) == 0 or (len(word) == 1 and word in punctuation_list):
        continue
    elif word[0] in punctuation_list:
        word = word[1:]
    elif word[-1] in punctuation_list:
        word = word[:-1]
    w_clean.append(word)

#print(frq_occur)

print(w_clean)
print(len(w_clean))
# Out:
# ['!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~']
# ...

# %%
book = "Imagine a vast sheet of paper on which straight Lines, Triangles, Squares, Pentagons, Hexagons, and other figures, instead of remaining fixed in their places, move freely about, on or in the surface, but without the power of rising above or sinking below it, very much like shadows--only hard and with luminous edges--and you will then have a pretty correct notion of my country and countrymen.  Alas, a few years ago, I should have said 'my universe':  but now my mind has been opened to higher views of things."
s_lower = book.lower()
words = s_lower.split()

punctuation_list = list(string.punctuation)

word_freq = {}
for w in words():
                                                # Remove leading and trailing punctuation
    words = word.strip(''.join(punctuation_list))
                                                # Remove any trailing quotation mark
    if w.endswith('"'):
        word = word[:-1]
                                                # Add the word to the dictionary or increment its count
    w = word.lower()                      # convert to lowercase to treat "Imagine" and "imagine" as the same word
    if w:
        word_freq[word] = word_freq.get(word, 0) + 1

# Print the list of distinct words and their frequencies
print(list(word_freq.keys()))
print(len(word_freq))


print(w_clean)
print(words)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18112\1195328208.py in <module>
#       6
#       7 word_freq = {}
# ----> 8 for w in words():
#       9                                                 # Remove leading and trailing punctuation
#      10     words = word.strip(''.join(punctuation_list))
#
# TypeError: 'list' object is not callable

# %%
import string

s = 'Imagine a vast sheet of paper on which straight lines, triangles, \
squares, pentagons, hexagons, and other figures, instead of remaining \
fixed in their places, move freely about on or in the surface, \
but without the power of rising above or sinking below it - very much like shadows. \
Only hard and with luminous edges. And you will then have a pretty correct notion of my \
country and countrymen. Alas, a few years ago, I should have said "my universe": \
but now my mind has been opened to higher views of things.'
s_lower = s.lower()       #Convert to lowercase 
s_words = s_lower.split()    #Split the lowercase string                     


punctuation_list = list(string.punctuation)     #Remove the punctuation
s_clean = []
for w in s_words:
    if len(w) == 1 and w in punctuation_list:
        continue
    elif w[0] in punctuation_list:
        s_clean.append(w[1:])
    elif w[-1] in punctuation_list:
        s_clean.append(w[:-1])
    else:
        s_clean.append(w)


w_counts = {}
for w in s_clean:
    if w in w_counts:         #count analysis on the words without punctuation
        w_counts[w] += 1
    else:
        w_counts[w] = 1


distinct_words = len(w_counts)
print(f"Distinct words: {distinct_words}")     #display the dictionary with the word counts and 
print("Word count:")                          #distinct words in original string
for w, count in w_counts.items():
    print(f"{w}: {count}")
# Out:
# Distinct words: 73
# Word count:
# imagine: 1
# a: 3
# vast: 1
# sheet: 1
# of: 5
# paper: 1
# on: 2
# which: 1
# straight: 1
# lines: 1
# triangles: 1
# squares: 1
# pentagons: 1
# hexagons: 1
# and: 4
# other: 1
# figures: 1
# instead: 1
# remaining: 1
# fixed: 1
# in: 2
# their: 1
# places: 1
# move: 1
# freely: 1
# about: 1
# or: 2
# the: 2
# surface: 1
# but: 2
# without: 1
# power: 1
# rising: 1
# above: 1
# sinking: 1
# below: 1
# it: 1
# very: 1
# much: 1
# like: 1
# shadows: 1
# only: 1
# hard: 1
# with: 1
# luminous: 1
# edges: 1
# you: 1
# will: 1
# then: 1
# have: 2
# pretty: 1
# correct: 1
# notion: 1
# my: 3
# country: 1
# countrymen: 1
# alas: 1
# few: 1
# years: 1
# ago: 1
# i: 1
# should: 1
# said: 1
# universe": 1
# now: 1
# mind: 1
# has: 1
# been: 1
# opened: 1
# to: 1
# higher: 1
# views: 1
# things: 1
